# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
INPUT_DIR = '/home/junseonglee/01_codes/input/rsna-2023-abdominal-trauma-detection'
train_meta = pd.read_csv(INPUT_DIR + '/train_series_meta.csv')
train_dicom_tags = pd.read_parquet(INPUT_DIR + '/train_dicom_tags.parquet')
train_meta
train_dicom_tags
# Out:
#          BitsAllocated  BitsStored  Columns ContentDate    ContentTime  \
# 0                   16          16      512    20230722  003306.881589
# 1                   16          16      512    20230722  003303.279137
# 2                   16          16      512    20230722  003343.090736
# 3                   16          16      512    20230722  003252.960345
# 4                   16          16      512    20230722  003155.059398
# ...                ...         ...      ...         ...            ...
# 1510368             16          16      512    20230721  232417.445248
# 1510369             16          16      512    20230721  232349.815191
# 1510370             16          16      512    20230721  232357.288770
# 1510371             16          16      512    20230721  232348.485715
# 1510372             16          16      512    20230721  232400.034504
#
#                                        FrameOfReferenceUID  HighBit  \
# ...
